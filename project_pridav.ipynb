# %%
import pandas as pd

# %% [markdown]
# ## Import data

# %% [markdown]
# #### dotacie data:

# %%
# inspired by https://stackoverflow.com/questions/71980264/how-to-create-automatic-variables-for-large-number-of-values-in-list-for-ex-li
# data 2008-2012:
s = ""
for i in range(2008, 2013):
    s+=f"data{i} = pd.read_excel('./data/dotacie{i}.xls')\n"
exec(s)

# TODO nacitat jednotlive harky, nie len takto hlupo
# TODO nacitat spravne nazvy stlpcov atd

# %%
display(data2008)
display(data2012)
# Out:
#             SR_2008              Unnamed: 1  \
# 0               VVŠ  Dotácia  celkom  BV+KV
# 1               NaN                     NaN
# 2     UK Bratislava                 2106235
# 3       UPJŠ Košice                  540141
# 4         PU Prešov                  476090
# ..              ...                     ...
# 66  VŠVU Bratislava                   97297
# 67    AU B.Bystrica                   64591
# 68    KU Ružomberok                  345102
# 69      UJS Komárno                   48923
# 70            Spolu                 9862490
#
#                                        Unnamed: 2  \
# 0           z toho:    B e ž n é    v ý d a v k y
# 1   Bežné dotácie na rok 2008 spolu (program 077)
# 2                                         2106235
# 3                                          540141
# 4                                          476090
# ..                                            ...
# 66                                          96894
# 67                                          64444
# 68                                         344637
# 69                                          48822
# 70                                        9822490
#
#                                          Unnamed: 3  \
# 0                                               NaN
# 1   Výkonové zložky (07711: MP+odv\n+TaS) + 0771201
# 2                                           1618682
# 3                                            406017
# 4                                            339846
# ..                                              ...
# 66                                            85516
# 67                                            55962
# 68                                           229892
# 69                                            36891
# 70                                          7686939
#
#                          Unnamed: 4  Unnamed: 5                  Unnamed: 6  \
# 0                               NaN         NaN                         NaN
# 1   Podprogram 07711- bežné dotácie  07711-mzdy  07711-odvody z miezd 35,2%
# 2                           1691723      937853                      330124
# 3                            440428      231634                       81535
# 4                            353447      187048                       65841
# ..                              ...         ...                         ...
# 66                            88070       46241                       16277
# 67                            55384       30948                       10894
# 68                           272651      123090                       43328
# 69                            36195       17725                        6239
# 70                          7987566     4348377                     1530630
#
#    Unnamed: 7                                 Unnamed: 8  \
# 0         NaN                                        NaN
# 1   07711-TaS  07711-štipendiá doktorandov  bez odvodov
# 2      190470                                     165142
# 3       62545                                      34819
# 4       69122                                      16881
# ..        ...                                        ...
# 66      16870                                       8682
# 67      11884                                       1658
# 68      56412                                       9077
# 69      11398                                        833
# 70    1199877                                     648682
#
#                                  Unnamed: 9  ...            Unnamed: 14  \
# 0                                       NaN  ...                    NaN
# 1   077 11 - záloha na  klinické pracoviská  ...  07715 - bežné dotácie
# 2                                     68134  ...                 254277
# 3                                     29895  ...                  69410
# 4                                     14555  ...                 104808
# ..                                      ...  ...                    ...
# 66                                      NaN  ...                   2696
# 67                                      NaN  ...                   6824
# 68                                    40744  ...                  64924
# 69                                      NaN  ...                  11098
# 70                                   260000  ...                1226869
#
#                                        Unnamed: 15  \
# 0                                              NaN
# 1   Prvok 0771501 -preddavok na sociálne štipendiá
# 2                                            91913
# 3                                            39131
# 4                                            65454
# ..                                             ...
# 66                                            1417
# 67                                            3924
# 68                                           44488
# 69                                            4338
# 70                                          460000
#
#                             Unnamed: 16                   Unnamed: 17  \
# 0                                   NaN                           NaN
# 1   Prvok 0771502 - motivačné štipendiá  Prvok 0771503 -bežné dotácie
# 2                                 30759                        131605
# 3                                  9650                         20629
# 4                                 11075                         28279
# ..                                  ...                           ...
# 66                                 1237                            42
# 67                                 1010                          1890
# 68                                 8912                         11524
# 69                                 1874                          4886
# 70                               238586                        528283
#
#          Unnamed: 18           Unnamed: 19         Unnamed: 20  \
# 0                NaN                   NaN                 NaN
# 1   0771503\nmzdy-ŠD  0771503-odvody 35,2%  0771503-TaS pre ŠD
# 2              48214                 16971               44177
# 3               7788                  2741                8262
# 4              10564                  3719                9879
# ..               ...                   ...                 ...
# 66                 0                     0                   0
# 67               929                   327                 603
# 68              3711                  1306                4460
# 69              1841                   648                2118
# 70            191868                 67539              198315
#
#                                           Unnamed: 21  \
# 0                                                 NaN
# 1   0771503-preddavok na príspevky na jedlá na rok...
# 2                                               15627
# 3                                                1258
# 4                                                2276
# ..                                                ...
# 66                                                  0
# 67                                                  0
# 68                                               1735
# 69                                                120
# 70                                              47184
#
#                      Unnamed: 22  \
# 0                            NaN
# 1   0771503- šport, kultúra, UPC
# 2                           6616
# 3                            580
# 4                           1841
# ..                           ...
# 66                            42
# 67                            31
# 68                           312
# 69                           159
# 70                         23377
#
#                                           Unnamed: 23
# 0                                                  KV
# 1   Prvok 0771201 - kapitálové dotácie na inštituc...
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 66                                                403
# 67                                                147
# 68                                                465
# 69                                                101
# 70                                              40000
#
# [71 rows x 24 columns]
#     Unnamed: 0               Unnamed: 1  \
# 0          NaN       T1-RD2012_RD2011'!
# 1          NaN   T1-RD2012_RD2011 (%)'!
# 2          NaN                  T2-KO'!
# 3          NaN                 T2-KAP'!
# 4          NaN              T3-vstupy'!
# 5          NaN           T4-štruk_077'!
# 6          NaN                T5a-abs'!
# 7          NaN            T5b-študent'!
# 8          NaN                T6a-abs'!
# 9          NaN              T6b-výkon'!
# 10         NaN          T6c-výkon-fak'!
# 11         NaN                T7-mzdy'!
# 12         NaN                 T8-TaS'!
# 13         NaN       T9-kultúra-šport'!
# 14         NaN    T9a_rozpis na TJ,ŠK'!
# 15         NaN            T10-prev_ŠD'!
# 16         NaN           T11-sumár_ŠD'!
# 17         NaN          T12-špecifiká'!
# 18         NaN         T13-sumár-špec'!
# 19         NaN                T14-VVZ'!
# 20         NaN                T14a-KA'!
# 21         NaN           T14b-podiely'!
# 22         NaN  T15-štipendiá-soc-Drš'!
# 23         NaN                T16-KKŠ'!
# 24         NaN  T17-Klinické-Zahr_lek'!
# 25         NaN           T18-Mot_štip'!
# 26         NaN    T19-počty studentov'!
# 27         NaN             T20-Publik'!
# 28         NaN               T20a-EPC'!
# 29         NaN               T20b-EUC'!
# 30         NaN           T21-Mobility'!
# 31         NaN              T22-praxe'!
#
#                                            Unnamed: 2
# 0   Tabuľka č. 1 - Rozpis dotácií verejným vysokým...
# 1   Tabuľka č. 1 - Rozpis dotácií verejným vysokým...
# 2   Tabuľka č. 2 - Výpočet koeficientu  odboru pre...
# 3   Tabuľka č.2 - Koeficient uplatnenia absolvento...
# 4   Tabuľka č. 3 - Hlavné vstupné a výstupné hodno...
# 5   Tabuľka č. 4 - Rozpis dotácie na programe 077 ...
# 6   Tabuľka č. 5a - Počty absolventov na VVŠ k 31....
# 7   Tabuľka č. 5b - Počty študentov na VVŠ k 31.10...
# 8   Tabuľka č. 6a - Výkon absolventov verejných vy...
# 9   Tabuľka č. 6b - Výkon verejných vysokých škôl ...
# 10  Tabuľka č. 6c - Výkon verejných vysokých škôl ...
# 11  Tabuľka č. 7 - Rozpis miezd na rok 2012 na pod...
# 12  Tabuľka č. 8 - Rozpis prostriedkov na TaS na r...
# 13  Tabuľka č. 9 - Rozpis príspevkov na šport, kul...
# 14  Tabuľka č. 9a - Rozpis finančných prostriedkov...
# 15  Tabuľka č. 10 - Výpočet príspevku na prevádzku...
# 16  Tabuľka č. 11 - Sumárne údaje o príspevkoch na...
# 17  Tabuľka č. 12 - Požiadavky vysokých škôl na po...
# 18  Tabuľka č. 13 - Príspevok na akceptované špeci...
# 19  Tabuľka č. 14 - Rozpis prostriedkov na mzdy a ...
# 20  Tabuľka č. 14a - Výpočet koeficientu výskumu a...
# 21  Tabuľka č. 14b - Podiely v jednotlivých oblast...
# 22  Tabuľka č. 15 - Rozpis sociálnych štipendií na...
# 23  Tabuľka č. 16 - Výpočet koeficientu kvalifikač...
# 24  Tabuľka č. 17 - Rozpis zálohy dotácie na výučb...
# 25  Tabuľka č. 18 - Rozpis dotácie na motivačné št...
# 26  Tabuľka č. 19 - Porovnanie počtov študentov k ...
# 27  Tabuľka č. 20 - Podiel VVŠ na publikačnej činn...
# 28  Tabuľka č. 20a - Publikačná činnosť z centráln...
# 29  Tabuľka č. 20b - Umelecká tvorba z centrálneho...
# 30  Tabuľka č. 21 - Dotácia na tovary a služby za ...
# 31  Tabuľka č. 22 - Dotácia na špeciálne praxe ver...

# %%
# toto nejde v pandas verzii 1.3.0, pricom v starsej verzii to islo... No idea why
pd.read_excel('./data/dotacie2013.xlsx')
# Out:
#     Unnamed: 0               Unnamed: 1  \
# 0          NaN       T1-RD2013_RD2012'!
# 1          NaN   T1-RD2013_RD2012 (%)'!
# 2          NaN                  T2-KO'!
# 3          NaN                 T2-KAP'!
# 4          NaN              T3-vstupy'!
# 5          NaN           T4-štruk_077'!
# 6          NaN                T5a-abs'!
# 7          NaN            T5b-študent'!
# 8          NaN                T6a-abs'!
# 9          NaN              T6b-výkon'!
# 10         NaN          T6c-výkon-fak'!
# 11         NaN                T7-mzdy'!
# 12         NaN                 T8-TaS'!
# 13         NaN       T9-kultúra-šport'!
# 14         NaN    T9a_rozpis na TJ,ŠK'!
# 15         NaN            T10-prev_ŠD'!
# 16         NaN           T11-sumár_ŠD'!
# 17         NaN          T12-špecifiká'!
# 18         NaN         T13-sumár-špec'!
# 19         NaN                T14-VVZ'!
# 20         NaN                T14a-KA'!
# 21         NaN           T14b-podiely'!
# 22         NaN       T14c-vstup_DG-ZG'!
# 23         NaN               T14d-Drš'!
# 24         NaN  T15-štipendiá-soc-Drš'!
# 25         NaN                T16-KKŠ'!
# 26         NaN  T17-Klinické-Zahr_lek'!
# 27         NaN           T18-Mot_štip'!
# 28         NaN    T19-počty studentov'!
# 29         NaN             T20-Publik'!
# 30         NaN               T20a-EPC'!
# 31         NaN               T20b-EUC'!
# 32         NaN           T21-Mobility'!
# 33         NaN              T22-praxe'!
#
#                                            Unnamed: 2
# 0   Tabuľka č. 1 - Rozpis dotácií verejným vysokým...
# 1   Tabuľka č. 1 - Percentuálny rozdiel rozpisu do...
# 2   Tabuľka č. 2 - Výpočet koeficientu  odboru pre...
# 3   Tabuľka č.2 - Koeficient uplatnenia absolvento...
# 4   Tabuľka č. 3 - Hlavné vstupné a výstupné hodno...
# 5   Tabuľka č. 4 - Rozpis dotácie na programe 077 ...
# 6   Tabuľka č. 5a - Počty absolventov na VVŠ k 31....
# 7   Tabuľka č. 5b - Počty študentov na VVŠ k 31.10...
# 8   Tabuľka č. 6a - Výkon absolventov verejných vy...
# 9   Tabuľka č. 6b - Výkon verejných vysokých škôl ...
# 10  Tabuľka č. 6c - Výkon verejných vysokých škôl ...
# 11  Tabuľka č. 7 - Rozpis miezd na rok 2013 na pod...
# 12  Tabuľka č. 8 - Rozpis prostriedkov na TaS na r...
# 13  Tabuľka č. 9 - Rozpis príspevkov na šport, kul...
# 14  Tabuľka č. 9a - Rozpis finančných prostriedkov...
# 15  Tabuľka č. 10 - Výpočet príspevku na prevádzku...
# 16  Tabuľka č. 11 - Sumárne údaje o príspevkoch na...
# 17  Tabuľka č. 12 - Finančné prostriedky na špecif...
# 18  Tabuľka č. 13 - Príspevok na akceptované špeci...
# 19  Tabuľka č. 14 - Rozpis prostriedkov na mzdy a ...
# 20  Tabuľka č. 14a - Výpočet koeficientu výskumu a...
# 21  Tabuľka č. 14b - Podiely v jednotlivých oblast...
# 22  Tabuľka č. 14c - Objem domácich a zahraničných...
# 23  Tabuľka č. 14d - Počet doktorandov po dizertač...
# 24  Tabuľka č. 15 - Rozpis sociálnych štipendií na...
# 25  Tabuľka č. 16 - Výpočet koeficientu kvalifikač...
# 26  Tabuľka č. 17 - Rozpis zálohy dotácie na výučb...
# 27  Tabuľka č. 18 - Rozpis dotácie na motivačné št...
# 28  Tabuľka č. 19 - Porovnanie počtov študentov k ...
# 29  Tabuľka č. 20 - Podiel VVŠ na publikačnej činn...
# 30  Tabuľka č. 20a - Publikačná činnosť z centráln...
# 31  Tabuľka č. 20b - Umelecká tvorba z centrálneho...
# 32  Tabuľka č. 21 - Dotácia na tovary a služby za ...
# 33  Tabuľka č. 22 - Dotácia na špeciálne praxe ver...

# %%
# a teda nejde ani tento kod kvoli tomu vyssie spomenutemu problemu :/
# nacitanie dat 2013-2022:
for i in range(2013, 2023):
    s+=f"data{i} = pd.read_excel('./data/dotacie{i}.xlsx')\n"
exec(s)

# %% [markdown]
# #### regzam data:

# %%
# toto nieco robi, ale nenacitava to vsetky data: vid Employment NaN, pricom tam malo nacitat este dalsie urovne ako University a pod.
regzam_data = pd.read_xml('./data/regzam_portalvs.xml')
display(regzam_data)
# Out:
#                 Id GivenName  FamilyName DegreePedagogicalAcademic  \
# 0      18799121690    Štefan       Kočan                      Doc.
# 1      14002860472     Dušan       Korgo                       DOC
# 2      17922733804       Ján     Buzalka                     prof.
# 3      16290288493     Jozef   Stieranka                     prof.
# 4      21401303068     Ľuboš       Wäldl                      doc.
# ...            ...       ...         ...                       ...
# 32730  12110964830      Joža      Spurný                      doc.
# 32731  13500390262   Marcela   Harčárová                      None
# 32732  17108478442      Jana    Juhásová                      None
# 32733  15917135755   Miriama    Kubušová                      None
# 32734  51680829014      Jana  Ochodnícka                      None
#
#       DegreeMaster DegreeDoctor  Employment  Guarantee
# 0            JUDr.         PhD.         NaN        NaN
# 1             JUDR          PHD         NaN        NaN
# 2            PhDr.         CSc.         NaN        NaN
# 3             Ing.         PhD.         NaN        NaN
# 4            JUDr.         PhD.         NaN        NaN
# ...            ...          ...         ...        ...
# 32730   JUDr.PhDr.        Ph.D.         NaN        NaN
# 32731         Mgr.         None         NaN        NaN
# 32732         Mgr.         None         NaN        NaN
# 32733         Mgr.         None         NaN        NaN
# 32734        PhDr.         None         NaN        NaN
#
# [32735 rows x 8 columns]

# %% [markdown]
# * súbory majú príponu `xls` pre roky 2008 - 2012, inak majú `xlsx`

# %%
nazvy = []
for y in range(2008, 2013):
    nazvy.append(f"data/dotacie{y}.xls")
for y in range(2013, 2023):
    nazvy.append(f"data/dotacie{y}.xlsx")

# %%
nazvy
# Out:
# ['data/dotacie2008.xls',
#  'data/dotacie2009.xls',
#  'data/dotacie2010.xls',
#  'data/dotacie2011.xls',
#  'data/dotacie2012.xls',
#  'data/dotacie2013.xlsx',
#  'data/dotacie2014.xlsx',
#  'data/dotacie2015.xlsx',
#  'data/dotacie2016.xlsx',
#  'data/dotacie2017.xlsx',
#  'data/dotacie2018.xlsx',
#  'data/dotacie2019.xlsx',
#  'data/dotacie2020.xlsx',
#  'data/dotacie2021.xlsx',
#  'data/dotacie2022.xlsx']

# %% [markdown]
# * `sheet_name=None` načíta všetky hárky zo súboru do dictionary, kde values sú dataframe-y a keys sú názvy hárkov

# %%
dotacie = {}

for i, file_name in enumerate(nazvy):
    dotacie[i+2008] = pd.read_excel(file_name, sheet_name=None)
#tuto ma problem s nejakymi datumami
# Out:
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D24 is marked as a date but the serial value 6343450 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D43 is marked as a date but the serial value 6975100 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell F44 is marked as a date but the serial value 7950880 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4389595 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D43 is marked as a date but the serial value 8878115 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4298228 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D43 is marked as a date but the serial value 8318468 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell C77 is marked as a date but the serial value 25107902.024399996 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D77 is marked as a date but the serial value 29182660.2 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4956630 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D26 is marked as a date but the serial value 4298228 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D46 is marked as a date but the serial value 8215407 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell C77 is marked as a date but the serial value 27232114.670799997 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D77 is marked as a date but the serial value 32441146.875 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4728948 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D26 is marked as a date but the serial value 4956630 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D46 is marked as a date but the serial value 8323404 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell C77 is marked as a date but the serial value 27905737.516799994 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D77 is marked as a date but the serial value 32225707.125 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 5343925 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D46 is marked as a date but the serial value 9480900 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 5062100 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D26 is marked as a date but the serial value 5343925 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D46 is marked as a date but the serial value 9676850 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4851050 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D26 is marked as a date but the serial value 5062100 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D46 is marked as a date but the serial value 10530350 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4826025 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D26 is marked as a date but the serial value 4851050 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell F46 is marked as a date but the serial value 9200135 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D23 is marked as a date but the serial value 4946000 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D26 is marked as a date but the serial value 4826025 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# C:\Users\roman\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell F46 is marked as a date but the serial value 9822340 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
